# %% [markdown]
# ### Participant 1

# %%
import json

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

RESPONSES = ['Strongly Disagree', 'Disagree', 'Neither', 'Agree', 'Strongly Agree']

# %matplotlib inline

data_file = 'UuBoG0_KiytpUZXX9V7Enw.txt'
  
# reading the data from the file
with open(data_file) as f:
    data = f.read()

print("Data type before reconstruction : ", type(data))
      
# reconstructing the data as a dictionary
js = json.loads(data)
  
print("Data type after reconstruction : ", type(js))
# Out:
# Data type before reconstruction :  <class 'str'>
# Data type after reconstruction :  <class 'dict'>

# %%
def get_text_file_responses(data_file):
    with open(data_file) as f:
        data = json.load(f)

    return data['responses']

# %% [markdown]
# Clean code of duplicates

# %%
def create_table(responses):
    df = pd.DataFrame()
    for key, value in responses.items():
        new_df = pd.json_normalize(value)
        new_df['image'] = key
        df = pd.concat([df, new_df])
    
    df['folder'] = df['image'].str.split('/').apply(lambda x: x[0])

    return df.replace(['noe'], ['nor'])\
             .replace(['std', 'dis', 'nor', 'agree', 'Strong_agree'],
                      ['Strongly Disagree', 'Disagree', 'Neither', 'Agree', 'Strongly Agree']
                     )

# %%
def cleanup_df(df):
    df.loc[df['id'] == 17, 'name'] = 'likert_4'
    # fix missing values
    df.fillna('Strongly Disagree', inplace=True)
    mapping = {'Strongly Disagree': 45, 45: 'likert_9'}
    df = df.replace({'id': mapping, 'name': mapping})\
           .replace(['noe'], ['nor'])\
           .replace(['std', 'dis', 'nor', 'agree', 'Strong_agree'],
                    ['Strongly Disagree', 'Disagree', 'Neither', 'Agree', 'Strongly Agree']
                   )f
    return df.drop_duplicates(['name', 'image'], keep='last')

# %%
df = create_table(cleanData['responses'])

# %%
df['folder'].value_counts()
# Out:
# science       59
# vis2          59
# news          57
# vis3          56
# government    56
# vis1          55
# Name: folder, dtype: int64

# %%
df = df.drop_duplicates(['name', 'image'], keep='last')

# %% [markdown]
# ## Visuals: Relationship between Visualization Type and Response Value

# %% [markdown]
# ### Example: Participant 1

# %%
df.loc[df['folder'] == 'news']
# Out:
#          name  id           response                                   image  \
# 0    likert_2  10  Strongly Disagree                         news/wsj466.png
# 1    likert_3  12              Agree                         news/wsj466.png
# 2    likert_4  19           Disagree                         news/wsj466.png
# 3    likert_5  24           Disagree                         news/wsj466.png
# 4    likert_7  31     Strongly Agree                         news/wsj466.png
# 5    likert_8  38            Neither                         news/wsj466.png
# 6    likert_9  42              Agree                         news/wsj466.png
# 7   likert_10  48            Neither                         news/wsj466.png
# 8   likert_11  54           Disagree                         news/wsj466.png
# 9    likert_6  29           Disagree                         news/wsj466.png
# 10   likert_1   3            Neither                         news/wsj466.png
# 0    likert_1   5  Strongly Disagree      news/economist_daily_chart_491.png
# 1    likert_2   7              Agree      news/economist_daily_chart_491.png
# 2    likert_3  12              Agree      news/economist_daily_chart_491.png
# 3    likert_4  19           Disagree      news/economist_daily_chart_491.png
# 4    likert_5  24           Disagree      news/economist_daily_chart_491.png
# 5    likert_6  29           Disagree      news/economist_daily_chart_491.png
# 6    likert_7  32              Agree      news/economist_daily_chart_491.png
# 7    likert_8  37              Agree      news/economist_daily_chart_491.png
# 8    likert_9  42              Agree      news/economist_daily_chart_491.png
# 9   likert_10  49           Disagree      news/economist_daily_chart_491.png
# 10  likert_11  52              Agree      news/economist_daily_chart_491.png
# 0    likert_1   4           Disagree                         news/wsj139.png
# 2    likert_2   8            Neither                         news/wsj139.png
# 3    likert_3  14           Disagree                         news/wsj139.png
# 4    likert_4  19           Disagree                         news/wsj139.png
# 5    likert_5  24           Disagree                         news/wsj139.png
# 6    likert_6  29           Disagree                         news/wsj139.png
# 7    likert_7  32              Agree                         news/wsj139.png
# 8    likert_8  39           Disagree                         news/wsj139.png
# 9    likert_9  42              Agree                         news/wsj139.png
# 10  likert_10  48            Neither                         news/wsj139.png
# 11  likert_11  52              Agree                         news/wsj139.png
# 0    likert_1   4           Disagree                         news/wsj530.png
# 1    likert_2   7              Agree                         news/wsj530.png
# 3    likert_3  13            Neither                         news/wsj530.png
# 4    likert_4  19           Disagree                         news/wsj530.png
# 5    likert_5  24           Disagree                         news/wsj530.png
# 6    likert_6  29           Disagree                         news/wsj530.png
# 7    likert_7  32              Agree                         news/wsj530.png
# 8    likert_8  39           Disagree                         news/wsj530.png
# 9    likert_9  42              Agree                         news/wsj530.png
# 10  likert_10  47              Agree                         news/wsj530.png
# 11  likert_11  52              Agree                         news/wsj530.png
# 0    likert_1   3            Neither  news/economist_daily_chart_102 (1).png
# 1    likert_2   8            Neither  news/economist_daily_chart_102 (1).png
# 2    likert_3  12              Agree  news/economist_daily_chart_102 (1).png
# 3    likert_4  18            Neither  news/economist_daily_chart_102 (1).png
# 4    likert_5  23            Neither  news/economist_daily_chart_102 (1).png
# 5    likert_6  27              Agree  news/economist_daily_chart_102 (1).png
# 6    likert_7  32              Agree  news/economist_daily_chart_102 (1).png
# 7    likert_8  37              Agree  news/economist_daily_chart_102 (1).png
# 8    likert_9  42              Agree  news/economist_daily_chart_102 (1).png
# 9   likert_10  48            Neither  news/economist_daily_chart_102 (1).png
# 10  likert_11  53            Neither  news/economist_daily_chart_102 (1).png
#
#    folder
# 0    news
# 1    news
# 2    news
# 3    news
# 4    news
# 5    news
# 6    news
# 7    news
# 8    news
# 9    news
# 10   news
# 0    news
# 1    news
# 2    news
# 3    news
# 4    news
# 5    news
# 6    news
# 7    news
# 8    news
# 9    news
# 10   news
# 0    news
# 2    news
# 3    news
# 4    news
# 5    news
# 6    news
# 7    news
# 8    news
# 9    news
# 10   news
# 11   news
# 0    news
# 1    news
# 3    news
# 4    news
# 5    news
# 6    news
# 7    news
# 8    news
# 9    news
# 10   news
# 11   news
# 0    news
# 1    news
# 2    news
# 3    news
# 4    news
# 5    news
# 6    news
# 7    news
# 8    news
# 9    news
# 10   news

# %%
sns.set_style('whitegrid')

# %%
df.loc[df['response'] == 'Strongly Disagree'].shape[0] / df.shape[0]
# Out:
# 0.1094224924012158

# %%
df.shape[0]
# Out:
# 329

# %%
df.head()
# Out:
#        name  id           response            image folder
# 0  likert_2  10  Strongly Disagree  news/wsj466.png   news
# 1  likert_3  12              Agree  news/wsj466.png   news
# 2  likert_4  19           Disagree  news/wsj466.png   news
# 3  likert_5  24           Disagree  news/wsj466.png   news
# 4  likert_7  31     Strongly Agree  news/wsj466.png   news

# %%
def plot_response(df, folder_name):

    sns.catplot(data=df.loc[df['folder'] == folder_name],
            x='response',
            kind="count",
            height=5,
            aspect=2,
            order=RESPONSES)

    plt.title(f"Responses for {folder_name.capitalize()} Visuals")
    
    count = 0
    for response in RESPONSES:
        height = df.loc[(df['response'] == response) &\
                       (df['folder'] == folder_name)
                      ].shape[0]
        total_rows = df.loc[df['folder'] == folder_name].shape[0]
        plt.annotate(f"{int((height/total_rows)*100)}%", (count, height+1))
        count += 1

# %%
gb = df.groupby(['folder', 'name', 'response']).count().reset_index()

# %%
gb.loc[(gb['name'] == 'likert_3') & (gb['folder'] == 'government')]
# Out:
#         folder      name        response  id  image
# 9   government  likert_3           Agree   2      2
# 10  government  likert_3        Disagree   2      2
# 11  government  likert_3  Strongly Agree   1      1

# %%
gb = concatenated.groupby(['folder', 'name', 'response']).count().reset_index()

# %%
gb
# Out:
#          folder      name           response  id  image
# 0    government  likert_1              Agree  23     23
# 1    government  likert_1           Disagree   1      1
# 2    government  likert_1            Neither  11     11
# 3    government  likert_1     Strongly Agree   9      9
# 4    government  likert_1  Strongly Disagree   1      1
# ..          ...       ...                ...  ..    ...
# 307        vis3  likert_9              Agree  27     27
# 308        vis3  likert_9           Disagree   3      3
# 309        vis3  likert_9            Neither   2      2
# 310        vis3  likert_9     Strongly Agree   7      7
# 311        vis3  likert_9  Strongly Disagree   6      6
#
# [312 rows x 5 columns]

# %%
concatenated
# Out:
#          name  id           response                    image      folder
# 0    likert_1   1     Strongly Agree          vis2/vis334.png        vis2
# 1    likert_2   8            Neither          vis2/vis334.png        vis2
# 2    likert_3  11     Strongly Agree          vis2/vis334.png        vis2
# 3    likert_4  16     Strongly Agree          vis2/vis334.png        vis2
# 4    likert_5  22              Agree          vis2/vis334.png        vis2
# ..        ...  ..                ...                      ...         ...
# 9    likert_7  32              Agree  government/whoJ45_1.png  government
# 10   likert_8  40  Strongly Disagree  government/whoJ45_1.png  government
# 11   likert_9  45  Strongly Disagree  government/whoJ45_1.png  government
# 12  likert_10  50  Strongly Disagree  government/whoJ45_1.png  government
# 13  likert_11  55  Strongly Disagree  government/whoJ45_1.png  government
#
# [2824 rows x 5 columns]

# %%
gb['folder'].unique()
# Out:
# array(['government', 'news', 'science', 'vis1', 'vis2', 'vis3'],
#       dtype=object)

# %%
len(gb['name'].unique())
# Out:
# 11

# %%
gb
# Out:
#          folder      name           response  id  image
# 0    government  likert_1              Agree  23     23
# 1    government  likert_1           Disagree   1      1
# 2    government  likert_1            Neither  11     11
# 3    government  likert_1     Strongly Agree   9      9
# 4    government  likert_1  Strongly Disagree   1      1
# ..          ...       ...                ...  ..    ...
# 307        vis3  likert_9              Agree  27     27
# 308        vis3  likert_9           Disagree   3      3
# 309        vis3  likert_9            Neither   2      2
# 310        vis3  likert_9     Strongly Agree   7      7
# 311        vis3  likert_9  Strongly Disagree   6      6
#
# [312 rows x 5 columns]

# %%
gb.loc[gb['response'] == "Agree", 'id'].values[0]
# Out:
# 23

# %%
gb.loc[gb['response'] == "Agree", 'id'].shape[0]
# Out:
# 60

# %%
def bar_values(gb):
    output = []
    for response in RESPONSES:
        height = gb.loc[gb['response'] == response, 'id']
        if height.shape[0] == 0:
            output.append(0)
        else:
            output.append(height.values[0])
    
    return output

# %%
bar_values(gb.loc[(gb['folder'] == 'vis3') & (gb['name'] == 'likert_9')])
# Out:
# [6, 3, 2, 27, 7]

# %%
def create_subplots(df, row_name, col_name, x_axis):
    count = 1
    for col in df[col_name].unique():
        for row in df[row_name].unique():
            plot_df = df.loc[(df[col_name] == col) & (df[row_name] == row)]
            gb = plot_df.groupby([col_name, row_name, x_axis]).count().reset_index()

            ax = plt.subplot(len(df['name'].unique()), len(df['folder'].unique()), count)
            plt.bar(x=RESPONSES, height=bar_values(gb), color=['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'])
            plt.xticks(rotation=90)
            ax.title.set_text(f"{col.capitalize()} | {row.capitalize()}")
            count += 1

# %%
plt.figure(figsize=(20, 35), dpi=80)
plt.subplots_adjust(left=0.1,
                    bottom=0.01,
                    right=0.9,
                    top=0.9,
                    hspace=0.99)
create_subplots(concatenated, 'folder', 'name', 'response')
plt.savefig('allCategories_allquestions_individualBarplot.png', dpi=200, bbox_inches = 'tight')

# %%
responses = ['Strongly Disagree', 'Disagree', 'Neither', 'Agree', 'Strongly Agree']

fig = sns.catplot(data=df.loc[df['folder'] == folder_name],
            x='response',
            kind="count",
            height=5,
            aspect=2,
            order=responses)

plt.title(f"Responses for {folder_name.capitalize()} Visuals")

count = 0
for response in responses:
    height = df.loc[(df['response'] == response) &\
                   (df['folder'] == folder_name)
                  ].shape[0]
    total_rows = df.loc[df['folder'] == folder_name].shape[0]
    plt.annotate(f"{int((height/total_rows)*100)}%", (count, height+1))
    count += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [111], line 3
#       1 responses = ['Strongly Disagree', 'Disagree', 'Neither', 'Agree', 'Strongly Agree']
# ----> 3 fig = sns.catplot(data=df.loc[df['folder'] == folder_name],
#       4             x='response',
#       5             kind="count",
#       6             height=5,
#       7             aspect=2,
#       8             order=responses)
#      10 plt.title(f"Responses for {folder_name.capitalize()} Visuals")
#      12 count = 0
#
# NameError: name 'folder_name' is not defined

# %%
plot_response(df, 'news')
plot_response(df, 'vis3')
plot_response(df, 'science')
plot_response(df, 'government')
plot_response(df, 'vis1')
plot_response(df, 'vis2')

# %% [markdown]
# ## All Participants

# %%
#1
data_file1 = 'UuBoG0_KiytpUZXX9V7Enw.txt'
  
# reading the data from the file
with open(data_file1) as f:
    data1 = f.read()
      
# reconstructing the data as a dictionary
js1 = json.loads(data1)

cleanData1 = {}

for key,value in js1.items():
    if key not in cleanData1.values():
        cleanData1[key] = value
df1 = create_table(cleanData1['responses'])


#2
data_file2 = 'mXQxt45qf3HmNZ8V6Y-gQg.txt'
  
# reading the data from the file
with open(data_file2) as f:
    data2 = f.read()
      
# reconstructing the data as a dictionary
js2 = json.loads(data2)

cleanData2 = {}

for key,value in js2.items():
    if key not in cleanData2.values():
        cleanData2[key] = value
df2 = create_table(cleanData2['responses'])

#3
data_file3 = 'C8sniClhFKJUWpkdJtBdMQ.txt'
  
# reading the data from the file
with open(data_file3) as f:
    data3 = f.read()
      
# reconstructing the data as a dictionary
js3 = json.loads(data3)

cleanData3 = {}

for key,value in js3.items():
    if key not in cleanData3.values():
        cleanData3[key] = value
df3 = create_table(cleanData3['responses'])

#4
data_file4 = 'C8sniClhFKJUWpkdJtBdMQ.txt'
  
# reading the data from the file
with open(data_file4) as f:
    data4 = f.read()
      
# reconstructing the data as a dictionary
js4 = json.loads(data4)

cleanData4 = {}

for key,value in js4.items():
    if key not in cleanData4.values():
        cleanData4[key] = value
df4 = create_table(cleanData4['responses'])

#5
data_file5 = 'CAst6IJu1mbQh4VGPrs7Mw.txt'
  
# reading the data from the file
with open(data_file5) as f:
    data5 = f.read()
      
# reconstructing the data as a dictionary
js5 = json.loads(data5)

cleanData5 = {}

for key,value in js5.items():
    if key not in cleanData5.values():
        cleanData5[key] = value
df5 = create_table(cleanData5['responses'])

#6
data_file6 = 'dYhVzMT6hTBJ8SCSDLgvBQ.txt'
  
# reading the data from the file
with open(data_file6) as f:
    data6 = f.read()
      
# reconstructing the data as a dictionary
js6 = json.loads(data6)

cleanData6 = {}

for key,value in js6.items():
    if key not in cleanData6.values():
        cleanData6[key] = value
df6 = create_table(cleanData6['responses'])

#7
data_file7 = 'FpVPTjgHaUWA_eIrRNWjdw.txt'
  
# reading the data from the file
with open(data_file7) as f:
    data7 = f.read()
      
# reconstructing the data as a dictionary
js7 = json.loads(data7)

cleanData7 = {}

for key,value in js7.items():
    if key not in cleanData7.values():
        cleanData7[key] = value
df7 = create_table(cleanData7['responses'])

#8
data_file8 = 'Sv_ZdnSoWDwmYWACFgeTcA.txt'
  
# reading the data from the file
with open(data_file8) as f:
    data8 = f.read()
      
# reconstructing the data as a dictionary
js8 = json.loads(data8)

cleanData8 = {}

for key,value in js8.items():
    if key not in cleanData8.values():
        cleanData8[key] = value
df8 = create_table(cleanData8['responses'])

#9
data_file9 = 'yVsZ2V9CJoo2z3VgB3jF0w.txt'
  
# reading the data from the file
with open(data_file9) as f:
    data9 = f.read()
      
# reconstructing the data as a dictionary
js9 = json.loads(data9)

cleanData9 = {}

for key,value in js9.items():
    if key not in cleanData9.values():
        cleanData9[key] = value
        
df9 = create_table(cleanData9['responses'])

#10
data_file10 = 'pPbJRJFp2YcuE504Awc29A.txt'
  
# reading the data from the file
with open(data_file10) as f:
    data10 = f.read()
      
# reconstructing the data as a dictionary
js10 = json.loads(data10)

cleanData10 = {}

for key,value in js10.items():
    if key not in cleanData10.values():
        cleanData10[key] = value
df10 = create_table(cleanData10['responses'])

#ALL
concatenated = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])

# %%
concatenated['id'].unique()
# Out:
# array([1, 8, 11, 16, 22, 27, 26, 31, 37, 39, 41, 46, 52, 42, 47, 36, 32,
#        29, 23, 17, 7, 2, 24, 18, 15, 28, 38, 25, 30, 48, 51, 10, 12, 40,
#        21, 6, 49, 50, 4, 19, 20, 55, 3, 9, 54, 14, 13, 33, 34, 44, 35, 53,
#        43, 'Strongly Disagree', 5], dtype=object)

# %%
concatenated
# Out:
#          name                 id           response                    image  \
# 0    likert_1                  1     Strongly Agree          vis2/vis334.png
# 1    likert_2                  8            Neither          vis2/vis334.png
# 2    likert_3                 11     Strongly Agree          vis2/vis334.png
# 3    likert_4                 16     Strongly Agree          vis2/vis334.png
# 4    likert_5                 22              Agree          vis2/vis334.png
# ..        ...                ...                ...                      ...
# 9    likert_7                 32              Agree  government/whoJ45_1.png
# 10   likert_8                 40  Strongly Disagree  government/whoJ45_1.png
# 11         45  Strongly Disagree                NaN  government/whoJ45_1.png
# 12  likert_10                 50  Strongly Disagree  government/whoJ45_1.png
# 13  likert_11                 55  Strongly Disagree  government/whoJ45_1.png
#
#         folder
# 0         vis2
# 1         vis2
# 2         vis2
# 3         vis2
# 4         vis2
# ..         ...
# 9   government
# 10  government
# 11  government
# 12  government
# 13  government
#
# [3521 rows x 5 columns]

# %%
concatenated.fillna('Strongly Disagree', inplace=True)
mapping = {'Strongly Disagree': 45, 45: 'likert_9'}
concatenated = concatenated.replace({'id': mapping, 'name': mapping})

# %%
concatenated['response'].unique()
# Out:
# array(['Strongly Agree', 'Neither', 'Agree', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
concatenated = concatenated.drop_duplicates(['name', 'image'], keep='last')

# %% [markdown]
# ### All Categories and Liketr Response for All Participants

# %%
sns.set_style('whitegrid')

plot_response(concatenated, 'news')
plot_response(concatenated, 'vis3')
plot_response(concatenated, 'science')
plot_response(concatenated, 'government')
plot_response(concatenated, 'vis1')
plot_response(concatenated, 'vis2')
plt.savefig('allCategories_individualBarplot.png', dpi=200, bbox_inches = 'tight')

# %% [markdown]
# ### Overall Responses for All Participants

# %%
gb_all = concatenated.groupby(['response']).count().reset_index()

# %%
gb_all
# Out:
#             response  name    id  image  folder
# 0              Agree  1002  1002   1002    1002
# 1           Disagree   605   605    605     605
# 2            Neither   391   391    391     391
# 3     Strongly Agree   354   354    354     354
# 4  Strongly Disagree   472   472    472     472

# %%
sns.catplot(data=concatenated,
            x='response',
            kind="count",
            height=5,
            aspect=2,
            order=RESPONSES)

plt.title(f"Overall Responses")
plt.savefig('overall.png', dpi=200, bbox_inches = 'tight')

# %% [markdown]
# ### Stacked Bar Chart

# %%
gb_all_stacked = concatenated.groupby(['folder', 'name', 'response']).count().reset_index()

# %%
gb_all_stacked_news = gb_all_stacked.loc[gb_all_stacked['folder'] == 'news']
del gb_all_stacked_news['image']

# %%
gb_all_stacked_news
# Out:
#     folder       name           response  id
# 53    news   likert_1              Agree  23
# 54    news   likert_1           Disagree   4
# 55    news   likert_1            Neither   4
# 56    news   likert_1     Strongly Agree  13
# 57    news   likert_1  Strongly Disagree   1
# 58    news  likert_10              Agree  13
# 59    news  likert_10           Disagree  10
# 60    news  likert_10            Neither  10
# 61    news  likert_10     Strongly Agree   4
# 62    news  likert_10  Strongly Disagree   8
# 63    news  likert_11              Agree  21
# 64    news  likert_11           Disagree   9
# 65    news  likert_11            Neither   5
# 66    news  likert_11     Strongly Agree   1
# 67    news  likert_11  Strongly Disagree   8
# 68    news   likert_2              Agree  17
# 69    news   likert_2           Disagree  11
# 70    news   likert_2            Neither   6
# 71    news   likert_2     Strongly Agree   8
# 72    news   likert_2  Strongly Disagree   3
# 73    news   likert_3              Agree  28
# 74    news   likert_3           Disagree   7
# 75    news   likert_3            Neither   1
# 76    news   likert_3     Strongly Agree   9
# 77    news   likert_4           Disagree  10
# 78    news   likert_4            Neither   5
# 79    news   likert_4     Strongly Agree   9
# 80    news   likert_5              Agree  25
# 81    news   likert_5           Disagree  11
# 82    news   likert_5            Neither   2
# 83    news   likert_5     Strongly Agree   7
# 84    news   likert_6              Agree  15
# 85    news   likert_6           Disagree  11
# 86    news   likert_6            Neither   5
# 87    news   likert_6     Strongly Agree   4
# 88    news   likert_6  Strongly Disagree  10
# 89    news   likert_7              Agree  28
# 90    news   likert_7           Disagree   3
# 91    news   likert_7            Neither   2
# 92    news   likert_7     Strongly Agree   8
# 93    news   likert_7  Strongly Disagree   4
# 94    news   likert_8              Agree  12
# 95    news   likert_8           Disagree  11
# 96    news   likert_8            Neither   6
# 97    news   likert_8     Strongly Agree   2
# 98    news   likert_8  Strongly Disagree  14
# 99    news   likert_9              Agree  21
# 100   news   likert_9           Disagree   3
# 101   news   likert_9            Neither   3
# 102   news   likert_9     Strongly Agree  13
# 103   news   likert_9  Strongly Disagree   5

# %%
gb_all_stacked_news = pd.pivot_table(data=gb_all_stacked_news, index=['name'], columns=['response'], values='id')

# %%
gb_all_stacked_news
# Out:
# response   Agree  Disagree  Neither  Strongly Agree  Strongly Disagree
# name
# likert_1    23.0       4.0      4.0            13.0                1.0
# likert_10   13.0      10.0     10.0             4.0                8.0
# likert_11   21.0       9.0      5.0             1.0                8.0
# likert_2    17.0      11.0      6.0             8.0                3.0
# likert_3    28.0       7.0      1.0             9.0                NaN
# likert_4     NaN      10.0      5.0             9.0                NaN
# likert_5    25.0      11.0      2.0             7.0                NaN
# likert_6    15.0      11.0      5.0             4.0               10.0
# likert_7    28.0       3.0      2.0             8.0                4.0
# likert_8    12.0      11.0      6.0             2.0               14.0
# likert_9    21.0       3.0      3.0            13.0                5.0

# %%
ax1 = gb_all_stacked_news.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax1.set_title('News', fontsize=20)
plt.savefig('news.png', dpi=200, bbox_inches = 'tight')

# %%
#'news' 'vis3' 'science' 'government' 'vis1' 'vis2'

gb_all_stacked_vis3 = gb_all_stacked.loc[gb_all_stacked['folder'] == 'vis3']
del gb_all_stacked_vis3['image']
gb_all_stacked_vis3 = pd.pivot_table(data=gb_all_stacked_vis3, index=['name'], columns=['response'], values='id')
ax2 = gb_all_stacked_vis3.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax2.set_title('Vis3', fontsize=20)
plt.savefig('vis3.png', dpi=200, bbox_inches = 'tight')

# %%
gb_all_stacked_science = gb_all_stacked.loc[gb_all_stacked['folder'] == 'science']
del gb_all_stacked_science['image']
gb_all_stacked_science = pd.pivot_table(data=gb_all_stacked_science, index=['name'], columns=['response'], values='id')
ax3 = gb_all_stacked_science.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax3.set_title('Science', fontsize=20)
plt.savefig('science.png', dpi=200, bbox_inches = 'tight')

# %%
gb_all_stacked_government = gb_all_stacked.loc[gb_all_stacked['folder'] == 'government']
del gb_all_stacked_government['image']
gb_all_stacked_government = pd.pivot_table(data=gb_all_stacked_government, index=['name'], columns=['response'], values='id')
ax4 = gb_all_stacked_government.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax4.set_title('Government', fontsize=20)
plt.savefig('government.png', dpi=200, bbox_inches = 'tight')

# %%
gb_all_stacked_vis1 = gb_all_stacked.loc[gb_all_stacked['folder'] == 'vis1']
del gb_all_stacked_vis1['image']
gb_all_stacked_vis1 = pd.pivot_table(data=gb_all_stacked_vis1, index=['name'], columns=['response'], values='id')
ax5 = gb_all_stacked_vis1.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax5.set_title('Vis1', fontsize=20)
plt.savefig('vis1.png', dpi=200, bbox_inches = 'tight')

# %%
gb_all_stacked_vis2 = gb_all_stacked.loc[gb_all_stacked['folder'] == 'vis2']
del gb_all_stacked_vis2['image']
gb_all_stacked_vis2 = pd.pivot_table(data=gb_all_stacked_vis2, index=['name'], columns=['response'], values='id')
ax6 = gb_all_stacked_vis2.plot.bar(stacked=True, color =['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0'], figsize=(8,6))
ax6.set_title('Vis2', fontsize=20)
plt.savefig('vis2.png', dpi=200, bbox_inches = 'tight')
